# %% [markdown]
# # Subject: test_regrtest_b
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/regrtestdata/import_from_tests/test_regrtest_b

# %% [markdown]
# ### File: util.py

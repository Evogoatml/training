# %% [markdown]
# # Subject: bar
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_unittest/namespace_test_pkg/bar

# %% [markdown]
# ### File: test_bar.py

# %%
import unittest

class PassingTest(unittest.TestCase):
    def test_true(self):
        self.assertTrue(True)

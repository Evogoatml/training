# %% [markdown]
# # Subject: module_and_namespace_package
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/module_and_namespace_package

# %% [markdown]
# ### File: a_test.py

# %%
attr = 'in module'

# %% [markdown]
# # Subject: package4
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_import/data/package4

# %% [markdown]
# ### File: submodule.py

# %%
attr = 'submodule'
class A:
    attr = 'submodule'

# %% [markdown]
# # Subject: tokenizedata
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/tokenizedata

# %% [markdown]
# ### File: bad_coding.py

# %%
# -*- coding: uft-8 -*-

# %% [markdown]
# ### File: bad_coding2.py

# %%
﻿#coding: utf8
print('我')

# %% [markdown]
# ### File: badsyntax_3131.py

# %%
# -*- coding: utf-8 -*-
€ = 2

# %% [markdown]
# ### File: badsyntax_pep3120.py

# %% [markdown]
# ### File: coding20731.py

# %%
#coding:latin1

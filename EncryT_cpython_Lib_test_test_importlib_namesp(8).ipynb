# %% [markdown]
# # Subject: child
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/project2/parent/child

# %% [markdown]
# ### File: two.py

# %%
attr = 'parent child two'

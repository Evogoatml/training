# %% [markdown]
# # Subject: test_import
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_import

# %% [markdown]
# ### File: __main__.py

# %%
import unittest

unittest.main('test.test_import')

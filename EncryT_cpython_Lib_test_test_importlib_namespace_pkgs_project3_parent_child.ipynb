# %% [markdown]
# # Subject: child
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/project3/parent/child

# %% [markdown]
# ### File: three.py

# %%
attr = 'parent child three'

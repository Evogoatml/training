# %% [markdown]
# # Subject: subpkg
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_import/data/circular_imports/subpkg

# %% [markdown]
# ### File: subpackage2.py

# %%
#from .util import util
from .. import subpackage

# %% [markdown]
# ### File: util.py

# %%
def util():
    pass

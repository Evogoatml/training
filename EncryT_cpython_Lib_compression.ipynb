# %% [markdown]
# # Subject: compression
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/compression

# %% [markdown]
# ### File: bz2.py

# %%
import bz2
__doc__ = bz2.__doc__
del bz2

from bz2 import *

# %% [markdown]
# ### File: gzip.py

# %%
import gzip
__doc__ = gzip.__doc__
del gzip

from gzip import *

# %% [markdown]
# ### File: lzma.py

# %%
import lzma
__doc__ = lzma.__doc__
del lzma

from lzma import *

# %% [markdown]
# ### File: zlib.py

# %%
import zlib
__doc__ = zlib.__doc__
del zlib

from zlib import *

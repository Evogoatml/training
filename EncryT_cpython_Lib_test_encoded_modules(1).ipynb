# %% [markdown]
# # Subject: encoded_modules
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/encoded_modules

# %% [markdown]
# ### File: module_iso_8859_1.py

# %% [markdown]
# ### File: module_koi8_r.py

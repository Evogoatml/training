# %% [markdown]
# # Subject: test_warnings
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_warnings

# %% [markdown]
# ### File: __main__.py

# %%
import unittest

unittest.main('test.test_warnings')

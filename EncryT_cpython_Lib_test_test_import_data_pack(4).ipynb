# %% [markdown]
# # Subject: package3
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_import/data/package3

# %% [markdown]
# ### File: submodule.py

# %%
attr = 'submodule'
class A:
    attr = 'submodule'
class submodule:
    attr = 'rebound'
    class B:
        attr = 'rebound'

# %% [markdown]
# # Subject: child
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/project1/parent/child

# %% [markdown]
# ### File: one.py

# %%
attr = 'parent child one'

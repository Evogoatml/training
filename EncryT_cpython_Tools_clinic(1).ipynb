# %% [markdown]
# # Subject: clinic
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Tools/clinic

# %% [markdown]
# ### File: clinic.py

# %%
#!/usr/bin/env python3
#
# Argument Clinic
# Copyright 2012-2013 by Larry Hastings.
# Licensed to the PSF under a contributor agreement.
#
from libclinic.cli import main


if __name__ == "__main__":
    main()

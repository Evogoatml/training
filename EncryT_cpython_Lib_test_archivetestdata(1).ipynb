# %% [markdown]
# # Subject: archivetestdata
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/archivetestdata

# %% [markdown]
# ### File: testdata_module_inside_zip.py

# %%
# Test data file to be stored within a zip file.
FAVORITE_NUMBER = 5

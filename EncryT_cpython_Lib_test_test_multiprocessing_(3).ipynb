# %% [markdown]
# # Subject: test_multiprocessing_spawn
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_multiprocessing_spawn

# %% [markdown]
# ### File: test_manager.py

# %%
import unittest
from test._test_multiprocessing import install_tests_in_module_dict

install_tests_in_module_dict(globals(), 'spawn', only_type="manager")

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# ### File: test_misc.py

# %%
import unittest
from test._test_multiprocessing import install_tests_in_module_dict

install_tests_in_module_dict(globals(), 'spawn', exclude_types=True)

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# ### File: test_processes.py

# %%
import unittest
from test._test_multiprocessing import install_tests_in_module_dict

install_tests_in_module_dict(globals(), 'spawn', only_type="processes")

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# ### File: test_threads.py

# %%
import unittest
from test._test_multiprocessing import install_tests_in_module_dict

install_tests_in_module_dict(globals(), 'spawn', only_type="threads")

if __name__ == '__main__':
    unittest.main()

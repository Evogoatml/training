# %% [markdown]
# # Subject: zipfile
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/zipfile

# %% [markdown]
# ### File: __main__.py

# %%
from . import main

if __name__ == "__main__":
    main()

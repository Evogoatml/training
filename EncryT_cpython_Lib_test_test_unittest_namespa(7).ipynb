# %% [markdown]
# # Subject: namespace_test_pkg
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_unittest/namespace_test_pkg

# %% [markdown]
# ### File: test_foo.py

# %%
import unittest

class PassingTest(unittest.TestCase):
    def test_true(self):
        self.assertTrue(True)

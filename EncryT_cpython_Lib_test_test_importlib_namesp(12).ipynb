# %% [markdown]
# # Subject: foo
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/not_a_namespace_pkg/foo

# %% [markdown]
# ### File: one.py

# %%
attr = 'portion1 foo one'

# %% [markdown]
# # Subject: foo
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/both_portions/foo

# %% [markdown]
# ### File: one.py

# %%
attr = 'both_portions foo one'

# %% [markdown]
# ### File: two.py

# %%
attr = 'both_portions foo two'

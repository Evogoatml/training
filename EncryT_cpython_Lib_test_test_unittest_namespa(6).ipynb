# %% [markdown]
# # Subject: noop
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_unittest/namespace_test_pkg/noop

# %% [markdown]
# ### File: test_noop.py

# %%
import unittest

class PassingTest(unittest.TestCase):
    def test_true(self):
        self.assertTrue(True)

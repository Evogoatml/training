# %% [markdown]
# # Subject: foo
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/test_importlib/namespace_pkgs/portion2/foo

# %% [markdown]
# ### File: two.py

# %%
attr = 'portion2 foo two'

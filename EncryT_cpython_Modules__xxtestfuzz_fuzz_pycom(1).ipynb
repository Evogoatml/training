# %% [markdown]
# # Subject: fuzz_pycompile_corpus
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Modules/_xxtestfuzz/fuzz_pycompile_corpus

# %% [markdown]
# ### File: input1.py

# %%
from __future__ import annotations

def test() -> None:
    x: list[int] = []
    x: dict[int, str] = {}
    x: set[bytes] = {}
    print(5 + 42 * 3, x)

# %% [markdown]
# ### File: input2.py

# %%
class Foo(metaclass=42):
    __slots__ = ['x']
    pass

foo = Foo()

# %% [markdown]
# ### File: input3.py

# %%
def evens():
    i = 0
    while True:
        i += 1
        if i % 2 == 0:
            yield i

# %% [markdown]
# ### File: input4.py

# %%
async def hello(name: str):
    await name
    print(name)

# %% [markdown]
# ### File: input5.py

# %%
try:
    eval('importer exporter... really long matches')
except SyntaxError:
    print("nothing to see here")
finally:
    print("all done here")
    raise

# %% [markdown]
# ### File: input6.py

# %%
"""Some module docstring"""
import sys

def main():
    print("Hello world!", file=sys.stderr)

if __name__ == '__main__':
    main()

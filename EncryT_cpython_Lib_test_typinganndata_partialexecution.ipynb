# %% [markdown]
# # Subject: partialexecution
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/test/typinganndata/partialexecution

# %% [markdown]
# ### File: a.py

# %%
v1: int

from . import b

v2: int

# %% [markdown]
# ### File: b.py

# %%
from . import a

annos = a.__annotations__

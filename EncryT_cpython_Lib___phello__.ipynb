# %% [markdown]
# # Subject: __phello__
# Source: /home/devuser/edu_data/datasets/TrainingDB/EncryT/cpython/Lib/__phello__

# %% [markdown]
# ### File: spam.py

# %%
initialized = True

def main():
    print("Hello world!")

if __name__ == '__main__':
    main()
